# %%
# String concadination (aka how to put strings together)
# Suppose we want to create a string that says "subscribe to ______"
youtuber = "Akhil" # some string variable

# few ways to do this 
print("subscribe to " + youtuber)
print("subscribe to {}".format(youtuber))
print(f"subscribe to {youtuber}")
# Out:
# subscribe to Akhil
# subscribe to Akhil
# subscribe to Akhil

# %%
# My way of doing this

Name = input("Enter your name :")
school_collage_name = input("Enter your school or collage name :")
roll_no = int(input("Enter your roll no"))
course = "Data Science"
percent = float(input("Enter your percentage in class 12 :"))

word = (f"{Name} one the aspiring Data Science engineer. Studying in {school_collage_name} whose roll no is {roll_no} and he is \
         \nself learning Data Science form YT and online courses has now taken a {course} course fromIIT Guwhati and started learning \
         \nData Science and ya this person has brought {percent} in his class 12.")

print(word)
# Out:
# Akhil one the aspiring Data Science engineer. Studying in Disha Collage whose roll no is 5 and he is
# self learning Data Science form YT and online courses has now taken a Data Science course fromIIT Guwhati and started learning
# Data Science and ya this person has brought 72.5 in his class 12.
